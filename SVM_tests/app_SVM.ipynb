# %%
from sklearn import svm
import pandas as pd
# Out:
# C:\Users\joaol\AppData\Local\Temp\ipykernel_7796\1612636641.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\joaol\\OneDrive\\Documentos\\Codiguinhos\\Python\\Ciência de Dados\\Testes\\datasets-to-study\\wine.csv")
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
y = df.iloc[:, 0]
X = df.iloc[:, 1:]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clf = svm.SVC(kernel="linear").fit(X, y)

# %%
clf.predict(X_test)
# Out:
# array([1, 3, 2, 1, 2, 2, 1, 3, 2, 2, 3, 3, 1, 2, 3, 2, 1, 1, 3, 1, 2, 1,
#        1, 2, 2, 2, 2, 2, 2, 3, 1, 1, 2, 1, 1, 1, 3, 2, 2, 3, 1, 1, 2, 2,
#        2, 1, 3, 2, 3, 1, 3, 3, 1, 3], dtype=int64)

# %%
y_test
# Out:
# 54     1
# 151    3
# 63     2
# 55     1
# 123    2
# 121    2
# 7      1
# 160    3
# 106    2
# 90     2
# 141    3
# 146    3
# 5      1
# 98     2
# 168    3
# 80     2
# 33     1
# 18     1
# 61     2
# 51     1
# 66     2
# 37     1
# 4      1
# 104    2
# 60     2
# 111    2
# 126    2
# 86     2
# 112    2
# 164    3
# 26     1
# 56     1
# 129    2
# 45     1
# 8      1
# 44     1
# 161    3
# 92     2
# 94     2
# 174    3
# 24     1
# 30     1
# 93     2
# 101    2
# 113    2
# 19     1
# 135    3
# 74     2
# 144    3
# 16     1
# 131    3
# 138    3
# 40     1
# 158    3
# Name: Wine, dtype: int64
